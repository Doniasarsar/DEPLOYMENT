# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from flask import Flask, flash, request, redirect, url_for, render_template, session
from flask_mysqldb  import MySQL
import pymysql
import re
import urllib.request
import os
from werkzeug.utils import secure_filename
import scipy.misc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline
from skimage.io import imread, imshow
from os import listdir
from os.path import isfile, join
import numpy
import argparse
from PIL import Image
import glob 
import pandas as pd
import numpy as np
import math
from matplotlib import pyplot as plt
import pickle

app = Flask(__name__)

@app.route('/', methods=['GET'])
def hometypeassu():
    return render_template('login.html')

# %%
app.secret_key = 'cairocoders-ednalan'

mysql = MySQL()

# MySQL configurations
app.config['MYSQL_HOST'] = 'localhost'
app.config['MYSQL_USER'] = 'root'
app.config['MYSQL_PASSWORD'] = ''
app.config['MYSQL_DB'] = 'pi'
mysql.init_app(app)

# http://localhost:5000/ / - this will be the login page
@app.route('/login', methods=['GET', 'POST'])
def login():
    conn = mysql.connection
    cursor = conn.cursor()

    if request.method == 'POST':
        username = request.form['username']
        password = request.form['password']
        # Check if the username and password match in the database
        cursor.execute('SELECT * FROM accounts WHERE username = %s AND password = %s', (username, password))
        account = cursor.fetchone()

        if account:
            # Create session data for the logged-in user
            session['loggedin'] = True
            session['id'] = account[0]
            session['username'] = account[1]
            return redirect(url_for('profile'))
        else:
            msg = 'Incorrect username/password!'
            return render_template('login.html', msg=msg)

    return render_template('login.html')
@app.route('/profile')
def profile():
    conn = mysql.connection
    cursor = conn.cursor()

    if 'loggedin' in session:
        # Retrieve the account information for the logged-in user
        cursor.execute('SELECT * FROM accounts WHERE id = %s', (session['id'],))
        account = cursor.fetchone()

        if account:
            cursor.close()  # Close the cursor
            conn.close()  # Close the connection
            return render_template('profile.html', account=account)
    
    cursor.close()  # Close the cursor
    conn.close()  # Close the connection
    return redirect(url_for('login'))
@app.route('/dash')
def dash():
    # Placeholder for the dash endpoint
    return "Welcome to the dashboard"

# %%
@app.route('/register', methods=['GET', 'POST'])
def register():
    conn = mysql.connection
    cursor = conn.cursor()

    if request.method == 'POST':
        username = request.form['username']
        password = request.form['password']
        # Check if the username is already taken
        cursor.execute('SELECT * FROM accounts WHERE username = %s', (username,))
        account = cursor.fetchone()

        if account:
            msg = 'Username already exists!'
            return render_template('register.html', msg=msg)
        else:
            # Insert the new user into the database
            cursor.execute('INSERT INTO accounts (username, password) VALUES (%s, %s)', (username, password))
            conn.commit()
            msg = 'Registration successful!'
            return redirect(url_for(''))

    return render_template('register.html')

# %%
if __name__ == '__main__':
    app.run(debug=True, use_reloader=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [15/May/2023 15:58:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/May/2023 15:59:02] "POST /login HTTP/1.1" 302 -
# 127.0.0.1 - - [15/May/2023 15:59:02] "GET /profile HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\app.py", line 2464, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\app.py", line 2450, in wsgi_app
#     response = self.handle_exception(e)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\app.py", line 1867, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\HP\AppData\Local\Temp/ipykernel_11664/938754282.py", line 49, in profile
#
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\templating.py", line 137, in render_template
#     return _render(
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\templating.py", line 120, in _render
#     rv = template.render(context)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\jinja2\environment.py", line 1090, in render
#     self.environment.handle_exception()
#   File "C:\Users\HP\anaconda3\Lib\site-packages\jinja2\environment.py", line 832, in handle_exception
#     reraise(*rewrite_traceback_stack(source=source))
#   File "C:\Users\HP\anaconda3\Lib\site-packages\jinja2\_compat.py", line 28, in reraise
#     raise value.with_traceback(tb)
#   File "E:\finale\templates\profile.html", line 1, in top-level template code
#     {% extends 'layout.html' %}
#   File "E:\finale\templates\layout.html", line 55, in top-level template code
#     <a class="py-2 d-none d-md-inline-block" href="{{ url_for('logout') }}"
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\helpers.py", line 370, in url_for
#     return appctx.app.handle_url_build_error(error, endpoint, values)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\app.py", line 2216, in handle_url_build_error
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\helpers.py", line 357, in url_for
#     rv = url_adapter.build(
#   File "C:\Users\HP\anaconda3\Lib\site-packages\werkzeug\routing.py", line 2314, in build
#     raise BuildError(endpoint, values, method, self)
# werkzeug.routing.BuildError: Could not build url for endpoint 'logout'. Did you mean 'login' instead?
# 127.0.0.1 - - [15/May/2023 15:59:03] "GET /profile?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [15/May/2023 15:59:03] "GET /profile?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [15/May/2023 15:59:03] "GET /profile?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [15/May/2023 15:59:03] "GET /profile?__debugger__=yes&cmd=resource&f=ubuntu.ttf HTTP/1.1" 200 -
# 127.0.0.1 - - [15/May/2023 15:59:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/May/2023 15:59:35] "POST /login HTTP/1.1" 302 -
# Debugging middleware caught exception in streamed response at a point where response headers were already sent.
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\app.py", line 2464, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\app.py", line 2458, in wsgi_app
#     ctx.auto_pop(error)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\ctx.py", line 452, in auto_pop
#     self.pop(exc)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\ctx.py", line 438, in pop
#     app_ctx.pop(exc)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\ctx.py", line 238, in pop
#     self.app.do_teardown_appcontext(exc)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask\app.py", line 2321, in do_teardown_appcontext
#     func(exc)
#   File "C:\Users\HP\anaconda3\Lib\site-packages\flask_mysqldb\__init__.py", line 107, in teardown
#     ctx.mysql_db.close()
# MySQLdb.OperationalError: (2006, '')
# 127.0.0.1 - - [15/May/2023 15:59:35] "GET /profile HTTP/1.1" 200 -
